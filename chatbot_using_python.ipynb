# %%
# !pip install chatterbot
# Out:
# ...
#   ERROR: Command errored out with exit status 1:
#    command: 'C:\Users\Nikitha\anaconda3\python.exe' 'C:\Users\Nikitha\AppData\Local\Temp\pip-standalone-pip-jpkl04lt\__env_pip__.zip\pip' install --ignore-installed --no-user --prefix 'C:\Users\Nikitha\AppData\Local\Temp\pip-build-env-08vl0o2v\overlay' --no-warn-script-location --no-binary :none: --only-binary :none: -i https://pypi.org/simple -- setuptools 'wheel>0.32.0,<0.33.0' Cython 'cymem>=2.0.2,<2.1.0' 'preshed>=2.0.1,<2.1.0' 'murmurhash>=0.28.0,<1.1.0' 'thinc>=7.0.8,<7.1.0'
#        cwd: None
#   Complete output (286 lines):
# ...
#     ERROR: Command errored out with exit status 1:
# ...

# %%
# !pip install chatterbot_corpus    #basic chat sentences like hi hello how are you is contanied in this corpus

# %%
import nltk

# %%
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Nikitha\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
from nltk.tokenize import sent_tokenize

# %%
from nltk.tokenize import word_tokenize

# %%
text="Hello everyone. Welcome to GeeksforGeeks. You are studying NLP article"

# %%
print(sent_tokenize(text))
# Out:
# ['Hello everyone.', 'Welcome to GeeksforGeeks.', 'You are studying NLP article']

# %%
print(word_tokenize(text))
# Out:
# ['Hello', 'everyone', '.', 'Welcome', 'to', 'GeeksforGeeks', '.', 'You', 'are', 'studying', 'NLP', 'article']

# %%
from nltk.stem import WordNetLemmatizer

# %%
lemmatizer=WordNetLemmatizer()

# %%
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Nikitha\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
print("runs :",lemmatizer.lemmatize("runs"))
print("better :", lemmatizer.lemmatize("better",pos='a'))
# Out:
# runs : run
# better : good

# %%
from nltk.stem import PorterStemmer

# %%
ps=PorterStemmer()
words=['program','programmer','programming','programs']
for w in words:
  print(w,':',ps.stem(w))
# Out:
# program : program
# programmer : programm
# programming : program
# programs : program

# %%
# !pip install --upgrade chatterbot
# Out:
# ^C

# %%
nltk.download()
# Out:
# showing info https://raw.githubusercontent.com/nltk/nltk_data/gh-pages/index.xml
#   ERROR: Command errored out with exit status 1:
#    command: 'C:\Users\Nikitha\anaconda3\python.exe' 'C:\Users\Nikitha\AppData\Local\Temp\pip-standalone-pip-eqtf_ppg\__env_pip__.zip\pip' install --ignore-installed --no-user --prefix 'C:\Users\Nikitha\AppData\Local\Temp\pip-build-env-q_a907fw\overlay' --no-warn-script-location --no-binary :none: --only-binary :none: -i https://pypi.org/simple -- setuptools 'wheel>0.32.0,<0.33.0' Cython 'cymem>=2.0.2,<2.1.0' 'preshed>=2.0.1,<2.1.0' 'murmurhash>=0.28.0,<1.1.0' 'thinc>=7.0.8,<7.1.0'
#        cwd: None
#   Complete output (286 lines):
# ...
#     Using cached setuptools-68.2.2-py3-none-any.whl (807 kB)
# ...
#     Using cached wheel-0.32.3-py2.py3-none-any.whl (21 kB)
# ...
#     Using cached Cython-3.0.2-cp39-cp39-win_amd64.whl (2.8 MB)
# ...
#     Using cached cymem-2.0.8-cp39-cp39-win_amd64.whl (39 kB)
# ...
#     Using cached preshed-2.0.1.tar.gz (113 kB)
# ...

# %%
from chatterbot import ChatBot

# %% [markdown]
# ListTrainer helps us train our bot

# %%
from chatterbot.trainers import ListTrainer

# %%
your_bot=ChatBot(name='Niki_Bot', read_only=True,logic_adapters=['chatterbot.logic.MathematicalEvaluation','chatterbot.logic.BestMatch'])
#logic adapter tells the list of trainers used for making the chatbot, for example to solve mathematical problem and Best match to choose the best reply for the question.
